# %%
import matplotlib.pyplot as plt

# Define the sections from the provided data (hardcoded for direct execution)
sections = [
    {
        "title": "Observation from Sparse Embedding Approach Using BM25",
        "data": [
            {
                "SN": 1,
                "ChunkingType": "Overlapped",
                "Metrics": {
                    "Precision@K": {"K=1": 0.61, "K=2": 0.39, "K=3": 0.28, "K=4": 0.22, "K=5": 0.18},
                    "Recall@K": {"K=1": 0.54, "K=2": 0.67, "K=3": 0.72, "K=4": 0.76, "K=5": 0.78},
                    "F1Score": {"K=1": 0.56, "K=2": 0.48, "K=3": 0.40, "K=4": 0.34, "K=5": 0.29}
                }
            },
            {
                "SN": 2,
                "ChunkingType": "Recursive",
                "Metrics": {
                    "Precision@K": {"K=1": 0.64, "K=2": 0.38, "K=3": 0.27, "K=4": 0.21, "K=5": 0.18},
                    "Recall@K": {"K=1": 0.63, "K=2": 0.75, "K=3": 0.80, "K=4": 0.83, "K=5": 0.85},
                    "F1Score": {"K=1": 0.63, "K=2": 0.50, "K=3": 0.41, "K=4": 0.38, "K=5": 0.29}
                }
            },
            {
                "SN": 3,
                "ChunkingType": "Semantic",
                "Metrics": {
                    "Precision@K": {"K=1": 0.62, "K=2": 0.38, "K=3": 0.27, "K=4": 0.21, "K=5": 0.18},
                    "Recall@K": {"K=1": 0.60, "K=2": 0.74, "K=3": 0.79, "K=4": 0.83, "K=5": 0.85},
                    "F1Score": {"K=1": 0.61, "K=2": 0.50, "K=3": 0.40, "K=4": 0.34, "K=5": 0.29}
                }
            }
        ]
    },
    {
        "title": "Observation from Overleaped Chunks & Dense Embedding",
        "data": [
            {
                "SN": 1,
                "EmbeddingModel": "BAAI/bge-large-en-v1.5",
                "Metrics": {
                    "Precision@K": {"K=1": 0.66, "K=2": 0.43, "K=3": 0.31, "K=4": 0.26, "K=5": 0.21},
                    "Recall@K": {"K=1": 0.58, "K=2": 0.74, "K=3": 0.82, "K=4": 0.86, "K=5": 0.88},
                    "F1Score": {"K=1": 0.61, "K=2": 0.53, "K=3": 0.46, "K=4": 0.39, "K=5": 0.33}
                }
            },
            {
                "SN": 2,
                "EmbeddingModel": "intfloat/e5-large-v2",
                "Metrics": {
                    "Precision@K": {"K=1": 0.67, "K=2": 0.44, "K=3": 0.33, "K=4": 0.26, "K=5": 0.21},
                    "Recall@K": {"K=1": 0.59, "K=2": 0.76, "K=3": 0.83, "K=4": 0.86, "K=5": 0.88},
                    "F1Score": {"K=1": 0.62, "K=2": 0.55, "K=3": 0.46, "K=4": 0.39, "K=5": 0.33}
                }
            },
            {
                "SN": 3,
                "EmbeddingModel": "sentence-transformers/multi-qa-mpnet-base-dot-v1",
                "Metrics": {
                    "Precision@K": {"K=1": 0.55, "K=2": 0.38, "K=3": 0.30, "K=4": 0.23, "K=5": 0.20},
                    "Recall@K": {"K=1": 0.48, "K=2": 0.64, "K=3": 0.73, "K=4": 0.78, "K=5": 0.82},
                    "F1Score": {"K=1": 0.50, "K=2": 0.46, "K=3": 0.41, "K=4": 0.35, "K=5": 0.31}
                }
            },
            {
                "SN": 4,
                "EmbeddingModel": "sentence-transformers/all-mpnet-base-v2",
                "Metrics": {
                    "Precision@K": {"K=1": 0.55, "K=2": 0.37, "K=3": 0.29, "K=4": 0.23, "K=5": 0.19},
                    "Recall@K": {"K=1": 0.47, "K=2": 0.63, "K=3": 0.72, "K=4": 0.77, "K=5": 0.81},
                    "F1Score": {"K=1": 0.50, "K=2": 0.46, "K=3": 0.40, "K=4": 0.35, "K=5": 0.31}
                }
            },
            {
                "SN": 5,
                "EmbeddingModel": "sentence-transformers/all-MiniLM-L12-v2",
                "Metrics": {
                    "Precision@K": {"K=1": 0.53, "K=2": 0.35, "K=3": 0.25, "K=4": 0.20, "K=5": 0.17},
                    "Recall@K": {"K=1": 0.46, "K=2": 0.60, "K=3": 0.65, "K=4": 0.69, "K=5": 0.73},
                    "F1Score": {"K=1": 0.48, "K=2": 0.43, "K=3": 0.36, "K=4": 0.31, "K=5": 0.27}
                }
            }
        ]
    },
    {
        "title": "Observation from Recursive Chunks & Dense Embedding",
        "data": [
            {
                "SN": 1,
                "EmbeddingModel": "BAAI/bge-large-en-v1.5",
                "Metrics": {
                    "Precision@K": {"K=1": 0.68, "K=2": 0.43, "K=3": 0.30, "K=4": 0.24, "K=5": 0.19},
                    "Recall@K": {"K=1": 0.67, "K=2": 0.83, "K=3": 0.88, "K=4": 0.91, "K=5": 0.93},
                    "F1Score": {"K=1": 0.68, "K=2": 0.56, "K=3": 0.44, "K=4": 0.37, "K=5": 0.32}
                }
            },
            {
                "SN": 2,
                "EmbeddingModel": "intfloat/e5-large-v2",
                "Metrics": {
                    "Precision@K": {"K=1": 0.71, "K=2": 0.44, "K=3": 0.31, "K=4": 0.24, "K=5": 0.20},
                    "Recall@K": {"K=1": 0.70, "K=2": 0.85, "K=3": 0.91, "K=4": 0.94, "K=5": 0.97},
                    "F1Score": {"K=1": 0.69, "K=2": 0.58, "K=3": 0.46, "K=4": 0.38, "K=5": 0.33}
                }
            },
            {
                "SN": 3,
                "EmbeddingModel": "sentence-transformers/multi-qa-mpnet-base-dot-v1",
                "Metrics": {
                    "Precision@K": {"K=1": 0.50, "K=2": 0.34, "K=3": 0.26, "K=4": 0.21, "K=5": 0.17},
                    "Recall@K": {"K=1": 0.49, "K=2": 0.67, "K=3": 0.76, "K=4": 0.81, "K=5": 0.84},
                    "F1Score": {"K=1": 0.49, "K=2": 0.45, "K=3": 0.39, "K=4": 0.33, "K=5": 0.29}
                }
            },
            {
                "SN": 4,
                "EmbeddingModel": "sentence-transformers/all-mpnet-base-v2",
                "Metrics": {
                    "Precision@K": {"K=1": 0.56, "K=2": 0.37, "K=3": 0.27, "K=4": 0.21, "K=5": 0.17},
                    "Recall@K": {"K=1": 0.55, "K=2": 0.72, "K=3": 0.80, "K=4": 0.84, "K=5": 0.86},
                    "F1Score": {"K=1": 0.55, "K=2": 0.49, "K=3": 0.40, "K=4": 0.34, "K=5": 0.29}
                }
            },
            {
                "SN": 5,
                "EmbeddingModel": "sentence-transformers/all-MiniLM-L12-v2",
                "Metrics": {
                    "Precision@K": {"K=1": 0.51, "K=2": 0.31, "K=3": 0.23, "K=4": 0.19, "K=5": 0.16},
                    "Recall@K": {"K=1": 0.49, "K=2": 0.50, "K=3": 0.68, "K=4": 0.73, "K=5": 0.76},
                    "F1Score": {"K=1": 0.50, "K=2": 0.40, "K=3": 0.35, "K=4": 0.30, "K=5": 0.26}
                }
            }
        ]
    },
    {
        "title": "Observation from Semantic & Dense Embedding",
        "data": [
            {
                "SN": 1,
                "EmbeddingModel": "BAAI/bge-large-en-v1.5",
                "Metrics": {
                    "Precision@K": {"K=1": 0.65, "K=2": 0.40, "K=3": 0.29, "K=4": 0.23, "K=5": 0.19},
                    "Recall@K": {"K=1": 0.64, "K=2": 0.78, "K=3": 0.85, "K=4": 0.88, "K=5": 0.90},
                    "F1Score": {"K=1": 0.64, "K=2": 0.53, "K=3": 0.43, "K=4": 0.36, "K=5": 0.31}
                }
            },
            {
                "SN": 2,
                "EmbeddingModel": "intfloat/e5-large-v2",
                "Metrics": {
                    "Precision@K": {"K=1": 0.66, "K=2": 0.41, "K=3": 0.29, "K=4": 0.23, "K=5": 0.19},
                    "Recall@K": {"K=1": 0.64, "K=2": 0.78, "K=3": 0.85, "K=4": 0.88, "K=5": 0.91},
                    "F1Score": {"K=1": 0.65, "K=2": 0.53, "K=3": 0.43, "K=4": 0.36, "K=5": 0.31}
                }
            },
            {
                "SN": 3,
                "EmbeddingModel": "sentence-transformers/multi-qa-mpnet-base-dot-v1",
                "Metrics": {
                    "Precision@K": {"K=1": 0.47, "K=2": 0.32, "K=3": 0.25, "K=4": 0.20, "K=5": 0.17},
                    "Recall@K": {"K=1": 0.45, "K=2": 0.61, "K=3": 0.71, "K=4": 0.77, "K=5": 0.80},
                    "F1Score": {"K=1": 0.46, "K=2": 0.42, "K=3": 0.37, "K=4": 0.32, "K=5": 0.28}
                }
            },
            {
                "SN": 4,
                "EmbeddingModel": "sentence-transformers/all-mpnet-base-v2",
                "Metrics": {
                    "Precision@K": {"K=1": 0.47, "K=2": 0.32, "K=3": 0.25, "K=4": 0.20, "K=5": 0.17},
                    "Recall@K": {"K=1": 0.45, "K=2": 0.61, "K=3": 0.71, "K=4": 0.77, "K=5": 0.80},
                    "F1Score": {"K=1": 0.46, "K=2": 0.42, "K=3": 0.37, "K=4": 0.32, "K=5": 0.28}
                }
            },
            {
                "SN": 5,
                "EmbeddingModel": "sentence-transformers/all-MiniLM-L12-v2",
                "Metrics": {
                    "Precision@K": {"K=1": 0.62, "K=2": 0.38, "K=3": 0.27, "K=4": 0.21, "K=5": 0.18},
                    "Recall@K": {"K=1": 0.60, "K=2": 0.74, "K=3": 0.79, "K=4": 0.83, "K=5": 0.85},
                    "F1Score": {"K=1": 0.61, "K=2": 0.50, "K=3": 0.40, "K=4": 0.34, "K=5": 0.29}
                }
            }
        ]
    },
    {
        "title": "Observation from Overlapped Chunks & Hybrid Embedding",
        "data": [
            {
                "SN": 1,
                "EmbeddingModel": "BAAI/bge-large-en-v1.5",
                "Metrics": {
                    "Precision@K": {"K=1": 0.66, "K=2": 0.43, "K=3": 0.36, "K=4": 0.33, "K=5": 0.26},
                    "Recall@K": {"K=1": 0.58, "K=2": 0.74, "K=3": 0.82, "K=4": 0.86, "K=5": 0.88},
                    "F1Score": {"K=1": 0.61, "K=2": 0.53, "K=3": 0.46, "K=4": 0.39, "K=5": 0.34}
                }
            },
            {
                "SN": 2,
                "EmbeddingModel": "intfloat/e5-large-v2",
                "Metrics": {
                    "Precision@K": {"K=1": 0.67, "K=2": 0.44, "K=3": 0.33, "K=4": 0.26, "K=5": 0.21},
                    "Recall@K": {"K=1": 0.59, "K=2": 0.76, "K=3": 0.83, "K=4": 0.86, "K=5": 0.88},
                    "F1Score": {"K=1": 0.62, "K=2": 0.54, "K=3": 0.46, "K=4": 0.39, "K=5": 0.33}
                }
            },
            {
                "SN": 3,
                "EmbeddingModel": "sentence-transformers/multi-qa-mpnet-base-dot-v1",
                "Metrics": {
                    "Precision@K": {"K=1": 0.55, "K=2": 0.38, "K=3": 0.29, "K=4": 0.23, "K=5": 0.20},
                    "Recall@K": {"K=1": 0.48, "K=2": 0.63, "K=3": 0.73, "K=4": 0.78, "K=5": 0.82},
                    "F1Score": {"K=1": 0.50, "K=2": 0.46, "K=3": 0.41, "K=4": 0.35, "K=5": 0.31}
                }
            },
            {
                "SN": 4,
                "EmbeddingModel": "sentence-transformers/all-mpnet-base-v2",
                "Metrics": {
                    "Precision@K": {"K=1": 0.55, "K=2": 0.38, "K=3": 0.29, "K=4": 0.23, "K=5": 0.19},
                    "Recall@K": {"K=1": 0.47, "K=2": 0.63, "K=3": 0.72, "K=4": 0.77, "K=5": 0.81},
                    "F1Score": {"K=1": 0.50, "K=2": 0.46, "K=3": 0.40, "K=4": 0.35, "K=5": 0.31}
                }
            },
            {
                "SN": 5,
                "EmbeddingModel": "sentence-transformers/all-MiniLM-L12-v2",
                "Metrics": {
                    "Precision@K": {"K=1": 0.53, "K=2": 0.35, "K=3": 0.26, "K=4": 0.20, "K=5": 0.17},
                    "Recall@K": {"K=1": 0.46, "K=2": 0.60, "K=3": 0.65, "K=4": 0.69, "K=5": 0.73},
                    "F1Score": {"K=1": 0.48, "K=2": 0.43, "K=3": 0.36, "K=4": 0.31, "K=5": 0.27}
                }
            }
        ]
    },
    {
        "title": "Observation from Recursive Chunks & Hybrid Embedding",
        "data": [
            {
                "SN": 1,
                "EmbeddingModel": "BAAI/bge-large-en-v1.5",
                "Metrics": {
                    "Precision@K": {"K=1": 0.69, "K=2": 0.39, "K=3": 0.26, "K=4": 0.20, "K=5": 0.16},
                    "Recall@K": {"K=1": 0.68, "K=2": 0.75, "K=3": 0.77, "K=4": 0.78, "K=5": 0.79},
                    "F1Score": {"K=1": 0.68, "K=2": 0.51, "K=3": 0.39, "K=4": 0.32, "K=5": 0.27}
                }
            },
            {
                "SN": 2,
                "EmbeddingModel": "intfloat/e5-large-v2",
                "Metrics": {
                    "Precision@K": {"K=1": 0.71, "K=2": 0.38, "K=3": 0.26, "K=4": 0.19, "K=5": 0.16},
                    "Recall@K": {"K=1": 0.70, "K=2": 0.75, "K=3": 0.76, "K=4": 0.76, "K=5": 0.77},
                    "F1Score": {"K=1": 0.70, "K=2": 0.51, "K=3": 0.39, "K=4": 0.31, "K=5": 0.26}
                }
            },
            {
                "SN": 3,
                "EmbeddingModel": "sentence-transformers/multi-qa-mpnet-base-dot-v1",
                "Metrics": {
                    "Precision@K": {"K=1": 0.61, "K=2": 0.33, "K=3": 0.22, "K=4": 0.16, "K=5": 0.13},
                    "Recall@K": {"K=1": 0.60, "K=2": 0.65, "K=3": 0.65, "K=4": 0.67, "K=5": 0.67},
                    "F1Score": {"K=1": 0.61, "K=2": 0.44, "K=3": 0.33, "K=4": 0.27, "K=5": 0.23}
                }
            },
            {
                "SN": 4,
                "EmbeddingModel": "sentence-transformers/all-mpnet-base-v2",
                "Metrics": {
                    "Precision@K": {"K=1": 0.62, "K=2": 0.33, "K=3": 0.22, "K=4": 0.17, "K=5": 0.14},
                    "Recall@K": {"K=1": 0.60, "K=2": 0.65, "K=3": 0.65, "K=4": 0.66, "K=5": 0.67},
                    "F1Score": {"K=1": 0.61, "K=2": 0.44, "K=3": 0.33, "K=4": 0.27, "K=5": 0.23}
                }
            },
            {
                "SN": 5,
                "EmbeddingModel": "sentence-transformers/all-MiniLM-L12-v2",
                "Metrics": {
                    "Precision@K": {"K=1": 0.55, "K=2": 0.31, "K=3": 0.21, "K=4": 0.16, "K=5": 0.13},
                    "Recall@K": {"K=1": 0.54, "K=2": 0.60, "K=3": 0.61, "K=4": 0.62, "K=5": 0.63},
                    "F1Score": {"K=1": 0.55, "K=2": 0.41, "K=3": 0.31, "K=4": 0.25, "K=5": 0.21}
                }
            }
        ]
    }, 
    {
  "title": "Observation from Semantic Chunks & Hybrid Embedding",
  "data": [
    {
      "SN": 1,
      "EmbeddingModel": "BAAI/bge-large-en-v1.5",
      "Metrics": {
        "Precision@K": { "K=1": 0.65, "K=2": 0.37, "K=3": 0.25, "K=4": 0.19, "K=5": 0.15 },
        "Recall@K":    { "K=1": 0.63, "K=2": 0.71, "K=3": 0.72, "K=4": 0.72, "K=5": 0.73 },
        "F1Score":     { "K=1": 0.64, "K=2": 0.48, "K=3": 0.37, "K=4": 0.29, "K=5": 0.25 }
      }
    },
    {
      "SN": 2,
      "EmbeddingModel": "intfloat/e5-large-v2",
      "Metrics": {
        "Precision@K": { "K=1": 0.67, "K=2": 0.36, "K=3": 0.24, "K=4": 0.18, "K=5": 0.15 },
        "Recall@K":    { "K=1": 0.65, "K=2": 0.70, "K=3": 0.70, "K=4": 0.71, "K=5": 0.71 },
        "F1Score":     { "K=1": 0.65, "K=2": 0.47, "K=3": 0.36, "K=4": 0.29, "K=5": 0.25 }
      }
    },
    {
      "SN": 3,
      "EmbeddingModel": "sentence-transformers/multi-qa-mpnet-base-dot-v1",
      "Metrics": {
        "Precision@K": { "K=1": 0.57, "K=2": 0.30, "K=3": 0.21, "K=4": 0.16, "K=5": 0.13 },
        "Recall@K":    { "K=1": 0.55, "K=2": 0.59, "K=3": 0.60, "K=4": 0.60, "K=5": 0.60 },
        "F1Score":     { "K=1": 0.56, "K=2": 0.40, "K=3": 0.31, "K=4": 0.24, "K=5": 0.21 }
      }
    },
    {
      "SN": 4,
      "EmbeddingModel": "sentence-transformers/all-mpnet-base-v2",
      "Metrics": {
        "Precision@K": { "K=1": 0.57, "K=2": 0.31, "K=3": 0.21, "K=4": 0.16, "K=5": 0.13 },
        "Recall@K":    { "K=1": 0.55, "K=2": 0.60, "K=3": 0.61, "K=4": 0.61, "K=5": 0.61 },
        "F1Score":     { "K=1": 0.56, "K=2": 0.41, "K=3": 0.31, "K=4": 0.25, "K=5": 0.21 }
      }
    },
    {
      "SN": 5,
      "EmbeddingModel": "sentence-transformers/all-MiniLM-L12-v2",
      "Metrics": {
        "Precision@K": { "K=1": 0.51, "K=2": 0.28, "K=3": 0.19, "K=4": 0.14, "K=5": 0.12 },
        "Recall@K":    { "K=1": 0.49, "K=2": 0.54, "K=3": 0.55, "K=4": 0.55, "K=5": 0.55 },
        "F1Score":     { "K=1": 0.49, "K=2": 0.54, "K=3": 0.28, "K=4": 0.23, "K=5": 0.19 }
      }
    }
  ]
}
]

# %%
# Generate plots
for section in sections:
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    metrics = ['Precision@K', 'Recall@K', 'F1Score']
    k_values = list(range(1, 6))

    for idx, metric in enumerate(metrics):
        ax = axs[idx]
        for item in section['data']:
            label = item.get('ChunkingType', item.get('EmbeddingModel', 'Unknown'))
            metric_values = [item['Metrics'][metric][f'K={k}'] for k in k_values]
            ax.plot(k_values, metric_values, marker='o', label=label)
        ax.set_title(metric)
        ax.set_xlabel('K')
        ax.set_ylabel('Value')
        ax.set_ylim(0, 1)
        ax.set_xticks(k_values)
        ax.legend(loc='lower left', fontsize='small')
        ax.grid(True, linestyle='--', alpha=0.7)

    fig.suptitle(section['title'])
    fig.savefig(f"{section['title'].replace(' ', '_')}.png")
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt

# marker and line style options
markers = ['o', 's', '^', 'D', 'v', 'P', 'X']
linestyles = ['-', '--', '-.', ':']

# Generate plots
for section in sections:
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    metrics = ['Precision@K', 'Recall@K', 'F1Score']
    k_values = list(range(1, 6))

    for idx, metric in enumerate(metrics):
        ax = axs[idx]
        all_values = []

        for i, item in enumerate(section['data']):
            label = item.get('ChunkingType', item.get('EmbeddingModel', 'Unknown'))
            metric_values = [item['Metrics'][metric][f'K={k}'] for k in k_values]

            all_values.extend(metric_values)

            ax.plot(
                k_values,
                metric_values,
                marker=markers[i % len(markers)],
                linestyle=linestyles[i % len(linestyles)],
                linewidth=2,
                markersize=6,
                label=label
            )

        # dynamic Y-axis range
        y_min = min(all_values)
        y_max = max(all_values)
        margin = 0.02
        ax.set_ylim(y_min - margin, y_max + margin)

        ax.set_title(metric, fontsize=12)
        ax.set_xlabel('K')
        ax.set_ylabel('Value')
        ax.set_xticks(k_values)

        ax.legend(fontsize=8, frameon=True)
        ax.grid(True, linestyle='--', alpha=0.6)

    fig.suptitle(section['title'], fontsize=14)
    plt.tight_layout()

    fig.savefig(
        f"{section['title'].replace(' ', '_')}.png",
        dpi=300,
        bbox_inches="tight"
    )

    plt.show()

# %%
bert_data = {
    "Precision":[[0.89,0.88],[0.92,0.93],[0.90,0.90]],
    "Recall":[[0.92,0.92],[0.95,0.95],[0.94,0.94]],
    "F1":[[0.91,0.90],[0.94,0.94],[0.92,0.92]]
}

metrics=["Precision","Recall","F1"]
x=np.arange(len(models))
width=0.35

fig,axs=plt.subplots(1,3,figsize=(14,5))

for i,metric in enumerate(metrics):

    without=[bert_data[metric][j][0] for j in range(3)]
    withicl=[bert_data[metric][j][1] for j in range(3)]

    ax=axs[i]

    ax.bar(x-width/2,without,width,label="Without ICL",hatch="//")
    ax.bar(x+width/2,withicl,width,label="With ICL",hatch="..")

    ax.set_xticks(x)
    ax.set_xticklabels(models,rotation=20)
    ax.set_title(metric)
    ax.set_ylabel("Score")
    ax.grid(axis="y",linestyle="--",alpha=0.6)

axs[0].legend()
plt.suptitle("BERTScore Comparison of LLMs")
plt.tight_layout()
plt.show()

# %%
labels=["Relevance","Accuracy","Clarity","Helpfulness","Completeness","Safety"]

human_data={
"GPT-OSS:20B":[4.95,4.80,4.97,4.80,4.79,5.00],
"Gemma-3:12B":[4.98,4.85,4.92,4.86,4.83,5.00],
"Llama-3.1:8B":[4.97,4.81,4.93,4.84,4.76,5.00]
}

angles=np.linspace(0,2*np.pi,len(labels),endpoint=False)
angles=np.concatenate((angles,[angles[0]]))

fig=plt.figure(figsize=(7,7))
ax=plt.subplot(111,polar=True)

markers=['o','s','^']

for i,(model,values) in enumerate(human_data.items()):

    values=np.concatenate((values,[values[0]]))

    ax.plot(angles,values,
            marker=markers[i],
            linewidth=2,
            label=model)

ax.set_thetagrids(angles[:-1]*180/np.pi,labels)
ax.set_ylim(4.7,5)

plt.title("Human Evaluation Comparison of LLMs")
plt.legend(loc="upper right",bbox_to_anchor=(1.3,1.1))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

models = ["GPT-OSS:20B", "Gemma-3:12B", "Llama-3.1:8B"]
metrics = ["Precision", "Recall", "F1"]

rouge_data = {
    "ROUGE-1": {
        "Precision": [[0.58,0.58],[0.63,0.64],[0.50,0.51]],
        "Recall": [[0.71,0.67],[0.81,0.79],[0.84,0.83]],
        "F1": [[0.56,0.54],[0.67,0.68],[0.58,0.59]]
    },
    "ROUGE-2": {
        "Precision": [[0.44,0.43],[0.49,0.50],[0.37,0.38]],
        "Recall": [[0.47,0.43],[0.63,0.61],[0.62,0.60]],
        "F1": [[0.40,0.36],[0.52,0.52],[0.43,0.43]]
    },
    "ROUGE-L": {
        "Precision": [[0.53,0.52],[0.58,0.59],[0.45,0.46]],
        "Recall": [[0.62,0.58],[0.74,0.73],[0.76,0.74]],
        "F1": [[0.50,0.48],[0.61,0.62],[0.52,0.53]]
    }
}

width = 0.35
x = np.arange(len(models))

fig, axs = plt.subplots(1,3, figsize=(16,5))

for idx,(rouge,values) in enumerate(rouge_data.items()):

    ax = axs[idx]

    for i,metric in enumerate(metrics):

        without = [values[metric][j][0] for j in range(3)]
        withicl = [values[metric][j][1] for j in range(3)]

        offset = (i-1)*width

        ax.bar(x+offset-width/2,
               without,
               width/2,
               label=f"{metric} (No ICL)" if idx==0 else "",
               hatch="//")

        ax.bar(x+offset+width/2,
               withicl,
               width/2,
               label=f"{metric} (ICL)" if idx==0 else "",
               hatch="..")

    ax.set_title(rouge)
    ax.set_xticks(x)
    ax.set_xticklabels(models, rotation=20)
    ax.set_ylabel("Score")
    ax.grid(axis="y", linestyle="--", alpha=0.6)

axs[0].legend(fontsize=9)

plt.suptitle("ROUGE Score Comparison of LLMs (With vs Without ICL)", fontsize=14)

plt.tight_layout()

plt.savefig("rouge_comparison_bar_chart.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

models = ["GPT-OSS:20B", "Gemma-3:12B", "Llama-3.1:8B"]
metrics = ["ROUGE-1", "ROUGE-2", "ROUGE-L"]

# F1 scores only
without_icl = [
    [0.56, 0.67, 0.58],   # ROUGE-1
    [0.40, 0.52, 0.43],   # ROUGE-2
    [0.50, 0.61, 0.52]    # ROUGE-L
]

with_icl = [
    [0.54, 0.68, 0.59],
    [0.36, 0.52, 0.43],
    [0.48, 0.62, 0.53]
]

x = np.arange(len(models))
width = 0.35

fig, axs = plt.subplots(1,3, figsize=(14,5))

for i,metric in enumerate(metrics):

    ax = axs[i]

    ax.bar(
        x - width/2,
        without_icl[i],
        width,
        label="Without ICL",
        hatch="//",
        edgecolor="black"
    )

    ax.bar(
        x + width/2,
        with_icl[i],
        width,
        label="With ICL",
        hatch="..",
        edgecolor="black"
    )

    ax.set_title(metric + " (F1 Score)")
    ax.set_xticks(x)
    ax.set_xticklabels(models, rotation=20)
    ax.set_ylabel("F1 Score")
    ax.grid(axis='y', linestyle='--', alpha=0.6)

axs[0].legend()

plt.suptitle("ROUGE F1 Score Comparison Across LLMs (With vs Without ICL)", fontsize=14)

plt.tight_layout()

plt.savefig("rouge_f1_comparison.png", dpi=300, bbox_inches="tight")

plt.show()
